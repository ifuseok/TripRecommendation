# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from modeling.GRU_recommend_concat import *
from modeling.evaluation_trip import *
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Read Data and preprocess

# %%
# Read Session Data
data = pd.read_excel('../최종DB관리/Session_Detail_DB/Session_train_totalv2.xlsx')

# %%
data
# Out:
#        Session_id2  Session_id  Session_num Start_Date   End_Date      month  \
# 0                0           0            1 2015-10-03 2015-10-05 2015-10-05
# 1                0           0            3 2015-10-03 2015-10-05 2015-10-06
# 2                0           0            5 2015-10-03 2015-10-05 2015-10-07
# 3                0           0            6 2015-10-03 2015-10-05 2015-10-08
# 4                0           0            7 2015-10-03 2015-10-05 2015-10-09
# 5                0           0            8 2015-10-03 2015-10-05 2015-10-10
# 6                0           0            9 2015-10-03 2015-10-05 2015-10-11
# 7                0           0           10 2015-10-03 2015-10-05 2015-10-12
# 8                0           0           11 2015-10-03 2015-10-05 2015-10-13
# 9                0           0           12 2015-10-03 2015-10-05 2015-10-14
# 10               0           0           13 2015-10-03 2015-10-05 2015-10-15
# 11               0           0           14 2015-10-03 2015-10-05 2015-10-16
# 12               1           1            1 2015-10-03 2015-10-05 2015-10-17
# 13               1           1            3 2015-10-03 2015-10-05 2015-10-18
# 14               1           1            4 2015-10-03 2015-10-05 2015-10-19
# 15               1           1            6 2015-10-03 2015-10-05 2015-10-20
# 16               1           1            7 2015-10-03 2015-10-05 2015-10-21
# 17               1           1            8 2015-10-03 2015-10-05 2015-10-22
# 18               1           1            9 2015-10-03 2015-10-05 2015-10-23
# 19               1           1           10 2015-10-03 2015-10-05 2015-10-24
# 20               2           2            1 2015-10-03 2015-10-05 2015-10-25
# 21               2           2            2 2015-10-03 2015-10-05 2015-10-26
# 22               2           2            3 2015-10-03 2015-10-05 2015-10-27
# 23               2           2            5 2015-10-03 2015-10-05 2015-10-28
# 24               2           2            6 2015-10-03 2015-10-05 2015-10-29
# 25               2           2            7 2015-10-03 2015-10-05 2015-10-30
# 26               2           2            8 2015-10-03 2015-10-05 2015-10-31
# 27               2           2            9 2015-10-03 2015-10-05 2015-11-01
# 28               2           2           10 2015-10-03 2015-10-05 2015-11-02
# 29               2           2           11 2015-10-03 2015-10-05 2015-11-03
# ...            ...         ...          ...        ...        ...        ...
# 28977         4517        4033            2 2018-12-05 2018-12-06 2095-03-04
# 28978         4517        4033            3 2018-12-05 2018-12-06 2095-03-05
# 28979         4517        4033            4 2018-12-05 2018-12-06 2095-03-06
# 28980         4517        4033            5 2018-12-05 2018-12-06 2095-03-07
# 28981         4517        4033            6 2018-12-05 2018-12-06 2095-03-08
# 28982         4517        4033            7 2018-12-05 2018-12-06 2095-03-09
# 28983         4517        4033            8 2018-12-05 2018-12-06 2095-03-10
# 28984         4518        4034            1 2018-12-05 2018-12-06 2095-03-11
# 28985         4518        4034            2 2018-12-05 2018-12-06 2095-03-12
# 28986         4518        4034            3 2018-12-05 2018-12-06 2095-03-13
# 28987         4518        4034            4 2018-12-05 2018-12-06 2095-03-14
# 28988         4519        4035            1 2018-10-12 2018-10-14 2095-03-15
# 28989         4519        4035            2 2018-10-12 2018-10-14 2095-03-16
# 28990         4519        4035            3 2018-10-12 2018-10-14 2095-03-17
# 28991         4519        4035            4 2018-10-12 2018-10-14 2095-03-18
# 28992         4519        4035            5 2018-10-12 2018-10-14 2095-03-19
# 28993         4519        4035            6 2018-10-12 2018-10-14 2095-03-20
# 28994         4519        4035            7 2018-10-12 2018-10-14 2095-03-21
# 28995         4519        4035            8 2018-10-12 2018-10-14 2095-03-22
# 28996         4520        4036            1 2018-10-12 2018-10-14 2095-03-23
# 28997         4520        4036            2 2018-10-12 2018-10-14 2095-03-24
# 28998         4520        4036            3 2018-10-12 2018-10-14 2095-03-25
# 28999         4520        4036            4 2018-10-12 2018-10-14 2095-03-26
# 29000         4520        4036            5 2018-10-12 2018-10-14 2095-03-27
# 29001         4520        4036            6 2018-10-12 2018-10-14 2095-03-28
# 29002         4520        4036            7 2018-10-12 2018-10-14 2095-03-29
# 29003         4521        4037            1 2018-10-12 2018-10-14 2095-03-30
# 29004         4521        4037            2 2018-10-12 2018-10-14 2095-03-31
# 29005         4521        4037            3 2018-10-12 2018-10-14 2095-04-01
# 29006         4521        4037            4 2018-10-12 2018-10-14 2095-04-02
#
#        Long  Date_info  percent                  Spot
# 0         3          1     0.33            호스텔 유메 노마드
# 1         3          1     0.33             아리마 온천 마을
# 2         3          1     0.33             스테이크랜드 고베
# 3         3          1     0.33          스타벅스 기타노이진칸점
# 4         3          1     0.33           고베 로코 팜 고베점
# 5         3          1     0.33           고베 모토마치 상점가
# 6         3          1     0.33                  난킨마치
# 7         3          1     0.33                   로쇼키
# 8         3          1     0.33  고베 하버랜드 우미에 (구 모자이크)
# 9         3          1     0.33               고베 하버랜드
# 10        3          1     0.33              고베 포트 타워
# 11        3          1     0.33            호스텔 유메 노마드
# 12        3          2     0.67                 주오 호텔
# 13        3          2     0.67                  오사카성
# 14        3          2     0.67             오사카 역사박물관
# 15        3          2     0.67                  헵파이브
# 16        3          2     0.67             우메다 스카이빌딩
# 17        3          2     0.67                  신세카이
# 18        3          2     0.67                  츠텐카쿠
# 19        3          2     0.67                 주오 호텔
# 20        3          3     1.00                 주오 호텔
# 21        3          3     1.00             덴포잔 하버빌리지
# 22        3          3     1.00                  가이유칸
# 23        3          3     1.00                 에비스바시
# 24        3          3     1.00             신사이바시 상점가
# 25        3          3     1.00               하나마루 우동
# 26        3          3     1.00           다이마루 신사이바시점
# 27        3          3     1.00                  빅 스텝
# 28        3          3     1.00              코가류 타코야끼
# 29        3          3     1.00                아메리카무라
# ...     ...        ...      ...                   ...
# 28977     2          1     0.50       구로몬 시장 (쿠로몬 시장)
# 28978     2          1     0.50                  오사카성
# 28979     2          1     0.50         오사카 시립 주택 박물관
# 28980     2          1     0.50               규카츠 타케루
# 28981     2          1     0.50             헵파이브 대관람차
# 28982     2          1     0.50             우메다 스카이빌딩
# 28983     2          1     0.50                 나니와노유
# 28984     2          2     1.00                  나라공원
# 28985     2          2     1.00          마츠노야 돈카츠 나라점
# 28986     2          2     1.00            후시미 이나리 신사
# 28987     2          2     1.00                 교토 타워
# 28988     3          1     0.33              간사이 국제공항
# 28989     3          1     0.33            남바 오리엔탈 호텔
# 28990     3          1     0.33       구로몬 시장 (쿠로몬 시장)
# 28991     3          1     0.33                  에비노야
# 28992     3          1     0.33               사키모토 식빵
# 28993     3          1     0.33                  도톤보리
# 28994     3          1     0.33                  아지노야
# 28995     3          1     0.33            남바 오리엔탈 호텔
# 28996     3          2     0.67            남바 오리엔탈 호텔
# 28997     3          2     0.67                  오사카성
# 28998     3          2     0.67             우메다 스카이빌딩
# 28999     3          2     0.67             헵파이브 대관람차
# 29000     3          2     0.67             돔보리 리버크루즈
# 29001     3          2     0.67              동양정 우메다점
# 29002     3          2     0.67            남바 오리엔탈 호텔
# 29003     3          3     1.00            남바 오리엔탈 호텔
# 29004     3          3     1.00              오렌지 스트리트
# 29005     3          3     1.00           모토무라 규카츠 본점
# 29006     3          3     1.00              간사이 국제공항
#
# [28953 rows x 10 columns]

# %%
ids=data[data["Spot"]=='구리코 네온'].Session_id
check = 0
for i in ids:
    sums=data[data["Session_id"]==i]["Spot"].isin(['도톤보리']).sum()
    if sums == 0:
        check += 1
        data.loc[(data["Session_id"]==i)&(data["Spot"]=="구리코 네온"),"Spot"]="도톤보리"
    else:
        data.loc[(data["Session_id"]==i)&(data["Spot"]=="구리코 네온"),"Spot"]="삭제"

# %%
data2=data[data["Spot"]!='삭제']

# %%
# Read item data
spot = pd.read_excel('../최종DB관리/Spot_VSS/2019.02.13.최종_통합DB2.xlsx')

# %%
spot["city_sub"]=spot.city +'_' + spot.sublocality
lab = LabelEncoder()
spot["city_sub_encoder"] = lab.fit_transform(spot["city_sub"])

# %%
# merge item and session (with attribute that will use in model)
data_spot = data.merge(spot[["ID2","Spot","Tag_encoder",'City_encoder','city_sub_encoder',"State_encoder"]],on="Spot",how="left")

# %%
# session_length 1 delete
lst_1=list(data_spot.groupby("Session_id").size().index[np.where(data_spot.groupby('Session_id').size()==1)[0]])
data_spot = data_spot[~data_spot.Session_id.isin(lst_1)]

# %%
# train test split
train = data_spot[:21003]
test = data_spot[21003:]

# %% [markdown]
# # Train model

# %%
class args():
    is_training = True
    retraining = False
    rnn_size = [4000,150] #  ,1000, 20, 5 
    n_epochs = 50
    batch_size = 50
    dropout_p_hidden= 0.5
    learning_rate = 0.0001
    decay = 0.96
    decay_steps = 5e3
    initializer = 'xavier'
    init_as_normal = False
    reset_after_session = True
    session_key = 'Session_id'
    attribute_key =["ID2",'City_encoder'] # input attribute
    item_key = 'Spot'
    time_key = 'Session_num'
    grad_cap = 0
    attribute = [len(spot),spot.City_encoder.nunique()] #, ,spot.Tag_encoder.nunique()  ,spot.city_sub_encoder.nunique()
    n_items = len(spot)
    max_ckpt_keep = 100
    test_model = 1
    sigma=0
    checkpoint_dir = 'ckpt_model'
    loss = 'top1'
    final_act = 'linear'
    hidden_act = 'tanh'
    item_table = spot

# %%
tf.reset_default_graph()

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
arg = args()
models = GRU4Rec(sess,arg)

# %%
models.fit(train)
# Out:
# fitting model....
# Epoch 0	Step 1	lr: 0.000100	loss: 0.990551
# Epoch: 0 cost: 0.9176268577575684
# Epoch: 1 cost: 0.8406726717948914
# Epoch: 2 cost: 0.810366153717041
# Epoch: 3 cost: 0.7922488451004028
# Epoch: 4 cost: 0.776819109916687
# Epoch: 5 cost: 0.7658964395523071
# Epoch: 6 cost: 0.754551887512207
# Epoch: 7 cost: 0.7457354664802551
# Epoch: 8 cost: 0.737910270690918
# Epoch: 9 cost: 0.7315874099731445
# Epoch: 10 cost: 0.7234575748443604
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-86692735ca30> in <module>()
# ----> 1 models.fit(train)
#
# D:\2019.01.04~여행앱개발\TripRecommendation\modeling\GRU_recommend_concat.py in fit(self, data2)
#     268                     feed_dict = {self.X: in_idx, self.Y: out_idx,self.state: state}
#     269
# --> 270                     cost, state, step, lr, _ = self.sess.run(fetches, feed_dict=feed_dict)
#     271                     epoch_cost.append(cost)
#     272                     if np.isnan(cost):
#
# ~\Anaconda3\envs\for_tensor\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\for_tensor\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~\Anaconda3\envs\for_tensor\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~\Anaconda3\envs\for_tensor\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\for_tensor\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # Test model

# %%
class args():
    is_training = False
    retraining = False
    rnn_size = [4000,150] #  ,1000, 20, 5 
    n_epochs = 50
    batch_size = 50
    dropout_p_hidden= 1.0
    learning_rate = 0.00001
    decay = 0.96
    decay_steps = 5e3
    initializer = 'xavier'
    init_as_normal = False
    reset_after_session = True
    session_key = 'Session_id'
    attribute_key =["ID2",'City_encoder'] # input attribute
    item_key = 'Spot'
    time_key = 'Session_num'
    grad_cap = 0
    attribute = [len(spot),spot.City_encoder.nunique()] #, ,spot.Tag_encoder.nunique()  ,spot.city_sub_encoder.nunique()
    n_items = len(spot)
    max_ckpt_keep = 100
    test_model = 10
    sigma=0
    checkpoint_dir = 'ckpt_model'
    loss = 'top1'
    final_act = 'linear'
    hidden_act = 'tanh'
    item_table = spot

# %%
tf.reset_default_graph()

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
arg = args()
models = GRU4Rec(sess,arg)
# Out:
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-10

# %%
# Check epoch 10 each performance
for i in range(0,10):
    tf.reset_default_graph()
    config = tf.ConfigProto()
    config.gpu_options.allow_growth=True
    sess = tf.Session(config=config)
    arg.test_model = i
    models = GRU4Rec(sess,arg)
    l_old=evaluate_sessions_batch(models,test, session_key= 'Session_id', item_key='Spot', time_key= 'Session_num',batch_size=50)
    print("Epoch:",i)
    print("Recall :",l_old[0])
    print("mrr :",l_old[1])
    print("Unique_recommend_lst",len(set(np.array(l_old[2].Rec_lst.tolist()).reshape(-1))))
    print('-----------------------------------------------------------------------------')
# Out:
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-0
# D:\2019.01.04~여행앱개발\TripRecommendation\modeling\evaluation_trip.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_data.sort_values([session_key,time_key],inplace=True)
# Recall [0.12073074 0.30436855 0.40127085 0.450834   0.47466243]
# mrr [0.12073074 0.18859412 0.20195841 0.20584771 0.20718354]
# Unique_recommend_lst 645
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-1
# Recall [0.13582208 0.33264496 0.4141382  0.45528197 0.48339952]
# mrr [0.13582208 0.20592004 0.21698993 0.22024224 0.22183729]
# Unique_recommend_lst 569
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-2
# Recall [0.13518666 0.34217633 0.42366958 0.46528991 0.49626688]
# mrr [0.13518666 0.20851734 0.21941305 0.22271921 0.22446935]
# Unique_recommend_lst 582
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-3
# Recall [0.13550437 0.34344718 0.42922955 0.47275616 0.50738681]
# mrr [0.13550437 0.21006619 0.22165891 0.22516615 0.22710172]
# Unique_recommend_lst 578
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-4
# Recall [0.13613979 0.35266084 0.4355838  0.48292295 0.51850675]
# mrr [0.13613979 0.21380725 0.22499981 0.22875928 0.23076901]
# Unique_recommend_lst 599
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-5
# Recall [0.13661636 0.35059571 0.44177919 0.4918189  0.52613185]
# mrr [0.13661636 0.21365105 0.22594677 0.22987478 0.23178645]
# Unique_recommend_lst 611
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-6
# Recall [0.13629865 0.35631454 0.44384432 0.49833201 0.52978554]
# mrr [0.13629865 0.2148663  0.22661888 0.23089627 0.23266743]
# Unique_recommend_lst 600
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-7
# Recall [0.13645751 0.35583797 0.44765687 0.50007943 0.53089754]
# mrr [0.13645751 0.2144718  0.22664631 0.23075473 0.23248929]
# Unique_recommend_lst 595
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-8
# Recall [0.13709293 0.35647339 0.45003971 0.50325655 0.53216839]
# mrr [0.13709293 0.21440561 0.2268641  0.2310288  0.2326484 ]
# Unique_recommend_lst 608
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-9
# Recall [0.13534551 0.3567911  0.45178713 0.50071485 0.53296267]
# mrr [0.13534551 0.21387344 0.22653195 0.23037428 0.2321926 ]
# Unique_recommend_lst 604

# %% [markdown]
# # Retraining

# %%
class args():
    is_training = True
    retraining = True
    rnn_size = [4000,150] #  ,1000, 20, 5 
    n_epochs = 50
    batch_size = 50
    dropout_p_hidden= 0.5
    learning_rate = 0.00001
    decay = 0.96
    decay_steps = 5e3
    initializer = 'xavier'
    init_as_normal = False
    reset_after_session = True
    session_key = 'Session_id'
    attribute_key =["ID2",'City_encoder'] # input attribute
    item_key = 'Spot'
    time_key = 'Session_num'
    grad_cap = 0
    attribute = [len(spot),spot.City_encoder.nunique()] #, ,spot.Tag_encoder.nunique()  ,spot.city_sub_encoder.nunique()
    n_items = len(spot)
    max_ckpt_keep = 100
    test_model = 10
    sigma=0
    checkpoint_dir = 'ckpt_model'
    loss = 'top1'
    final_act = 'linear'
    hidden_act = 'tanh'
    item_table = spot

# %%
tf.reset_default_graph()

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
arg = args()
models = GRU4Rec(sess,arg)
# Out:
# INFO:tensorflow:Restoring parameters from ckpt_model/attribute_model-10

# %%
models.fit(train)
# Out:
# fitting model....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-86692735ca30> in <module>()
# ----> 1 models.fit(train)
#
# D:\2019.01.04~여행앱개발\TripRecommendation\modeling\GRU_recommend_concat.py in fit(self, data2)
#     268                     feed_dict = {self.X: in_idx, self.Y: out_idx,self.state: state}
#     269
# --> 270                     cost, state, step, lr, _ = self.sess.run(fetches, feed_dict=feed_dict)
#     271                     epoch_cost.append(cost)
#     272                     if np.isnan(cost):
#
# ~\Anaconda3\envs\for_tensor\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\for_tensor\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~\Anaconda3\envs\for_tensor\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~\Anaconda3\envs\for_tensor\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\for_tensor\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
